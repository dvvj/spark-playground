# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.context import SparkContext
from pyspark import SparkFiles
from pyspark.sql.session import SparkSession

# %%
spark = SparkSession.builder \
  .master("local[2]") \
  .appName("Hello PySpark") \
  .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0,org.apache.hadoop:hadoop-azure:3.3.2") \
  .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
  .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
  .getOrCreate()


# dataList = [("Java", 20000), ("Python", 100000), ("Scala", 3000)]
# df = spark.sparkContext.parallelize(dataList) \
#     .toDF(["Lang", "Score"])
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/03/14 08:43:43 WARN Utils: Your hostname, 5CG1403FF5 resolves to a loopback address: 127.0.1.1; using 172.19.238.145 instead (on interface eth0)
# 24/03/14 08:43:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/devvj/py310/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/devvj/.ivy2/cache
# The jars for the packages stored in: /home/devvj/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3263d0e5-749d-4fe7-80c7-2474f430249b;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# ...

# %%
# df.show()

# %%
# df1 = spark.read.format("delta").load("file:///mnt/c/dcb/dbg/SOH_KERS.decode.20240312")
# df1.show(truncate=False)

# %%
spark.conf.set("fs.azure.account.auth.type.testadls2u314.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.testadls2u314.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.testadls2u314.dfs.core.windows.net", "bdcb5240-9c0c-4f82-abd5-04316879c8d2")
spark.conf.set("fs.azure.account.oauth2.client.secret.testadls2u314.dfs.core.windows.net", "QzD8Q~74dxb8CkiQ-ZVowXdMkCEpkrPojJ-fLbfR")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.testadls2u314.dfs.core.windows.net", "https://login.microsoftonline.com/81fa766e-a349-4867-8bf4-ab35e250a08f/oauth2/token")

# df2 = spark.read.format("delta").load("abfss://rvdc@prodadls2u314.dfs.core.windows.net/temp/SOH_KERS.decode.20240312/")
df2 = spark.read.format("delta").load("abfss://rvdc@testadls2u314.dfs.core.windows.net/tmp/source_soh_phev/table/")
df2.show(truncate=False)
# Out:
# 24/03/14 08:43:57 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 9:>                                                          (0 + 1) / 1]
# ...
